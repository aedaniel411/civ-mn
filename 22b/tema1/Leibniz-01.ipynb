% %%
pi
% Out:
% error: graphics_toolkit: 2004h toolkit is not available
% error: called from
%     graphics_toolkit at line 84 column 5
%
%
%
% ans = 3.1416

% %%
format long

% %%
pi
% Out:
% ans = 3.141592653589793

% %%
n = 0;
suma = 0.0;
err = 100;

% ciclo
while ( err >= 0.009 )
    suma = suma + ( (-1)^n / (2*n + 1) );
    err = abs(pi - suma * 4);
    mipi = suma * 4.0 ;
    printf("%10d %10.7f %10.7f \n", n, pi, mipi);
    n = n + 1;
end
%- fin
%A = [n, pi, suma * 4];
%disp(A);
% Out:
%          0  3.1415927  4.0000000 [?2004l
%          1  3.1415927  2.6666667
%          2  3.1415927  3.4666667
%          3  3.1415927  2.8952381
%          4  3.1415927  3.3396825
%          5  3.1415927  2.9760462
%          6  3.1415927  3.2837385
%          7  3.1415927  3.0170718
%          8  3.1415927  3.2523659
%          9  3.1415927  3.0418396
%         10  3.1415927  3.2323158
%         11  3.1415927  3.0584028
%         12  3.1415927  3.2184028
%         13  3.1415927  3.0702546
%         14  3.1415927  3.2081857
%         15  3.1415927  3.0791534
%         16  3.1415927  3.2003655
%         17  3.1415927  3.0860798
%         18  3.1415927  3.1941879
%         19  3.1415927  3.0916238
%         20  3.1415927  3.1891848
%         21  3.1415927  3.0961615
%         22  3.1415927  3.1850504
%         23  3.1415927  3.0999440
%         24  3.1415927  3.1815767
%         25  3.1415927  3.1031453
%         26  3.1415927  3.1786170
%         27  3.1415927  3.1058897
% ...

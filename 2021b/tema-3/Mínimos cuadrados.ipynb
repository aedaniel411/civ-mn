% %% [markdown]
% ## Mínimos cuadrados

% %%
x = [1 2 3 4 5 6 7];
y = [4 7 9 10 9 7 4];

% %%
graphics_toolkit ("gnuplot")

% %%
plot (x, y, 'or')

% %%
A = [  7.  28.  140.  50. ;
      28. 140.  784. 200. ;
     140. 784. 4676. 946. ]
% Out:
% A =
%
%       7     28    140     50
%      28    140    784    200
%     140    784   4676    946

% %%
rref(A)
% Out:
% ans =
%
%    1.0000        0        0  -0.5714
%         0   1.0000        0   5.1429
%         0        0   1.0000  -0.6429

% %%
xx=linspace(0,8);
yy=-0.5714+(5.1429 .* xx)-(.6429 .* xx .* xx);

plot(xx,yy)

% %%
plot (x, y, 'or')
hold on
plot(xx,yy)
